# %% [markdown]
# # 00 — Context | Engineering Next-Generation Batteries
#
# **Reaction Selectivity Specifies Battery Constraints**
#
# This starter notebook frames the repository as an engineering roadmap. The goal is not to summarize every battery chemistry, but to organize next-generation battery work around leading specifications, sustainable collaboration, engineering constraints, and measured performance.

# %% [markdown]
# ## Engineering spine
#
# ```text
# Energy-storage reactions
#         ↓
# Reaction selectivity
#         ↓
# Competing reactions
#         ↓
# Engineering constraints
#         ↓
# Battery limits
#         ↓
# Measured performance
# ```

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT / "src"))

from next_gen_batteries import build_constraint_graph, draw_constraint_graph

FIGURES = ROOT / "figures"
FIGURES.mkdir(exist_ok=True)

G = build_constraint_graph()
print(f"nodes={G.number_of_nodes()}, edges={G.number_of_edges()}")

# %%
draw_constraint_graph(FIGURES / "00_constraint_graph.png")

# %% [markdown]
# ## Engineering collaboration
#
# | Area | Action | Role |
# |---|---|---|
# | Materials | stabilize | enable durable energy-storage reactions |
# | Interfaces | control | guide reactions at phase boundaries |
# | Electrolytes | transport | support ion motion within operating windows |
# | Manufacturing | repeat | preserve design intent at scale |
# | Diagnostics | measure | detect limits before failure |
# | Physics + AI | predict | connect mechanisms to design choices |

# %%
import pandas as pd

roadmap = pd.DataFrame([
    ("00_context", "Engineering objective and constraint map", "starter"),
    ("07_reaction_pathways", "Energy-storage and competing pathways", "planned"),
    ("13_reaction_selectivity", "Selectivity as a leading specification", "planned"),
    ("17_interfaces", "Interface control and stability", "planned"),
    ("23_electrolytes", "Transport, windows, and compatibility", "planned"),
    ("29_manufacturing", "Repeatability and scalable quality", "planned"),
    ("37_diagnostics", "Measuring degradation and health", "planned"),
    ("43_modeling_ai", "Physics-informed prediction", "planned"),
    ("49_constraint_graphs", "Integrated design graph", "planned"),
    ("53_future_chemistries", "Viable alternatives and open questions", "planned"),
], columns=["notebook", "theme", "status"])
roadmap

# %% [markdown]
# ## Next step
#
# Use this notebook as the stable entry point. After the seminar, update the context section with any specific engineering targets, viable chemistry directions, and manufacturing constraints emphasized by the speaker.

# %%
# Final download cell: zip generated figures/assets for easy download in Colab/Jupyter.
from pathlib import Path
import zipfile
from IPython.display import FileLink, display

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
zip_path = ROOT / "next-gen-batteries-assets.zip"
with zipfile.ZipFile(zip_path, "w", zipfile.ZIP_DEFLATED) as zf:
    for path in (ROOT / "figures").glob("*"):
        if path.is_file():
            zf.write(path, path.relative_to(ROOT))

print(zip_path)
display(FileLink(str(zip_path)))
